# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Task 1
# ![image.png](attachment:image.png)

# %% [markdown]
# # Task 2
# ![image.png](attachment:image.png)

# %% [markdown]
# # Task 3
# ![image.png](attachment:image.png)

# %% [markdown]
# # Task 4
# ![image.png](attachment:image.png)
