# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# Чем результат сложения векторов (новый вектор) ближе к одному из исходных векторов, тем больший акцент имеет слово, рядом с которым находится новый вектор.

# %% [markdown]
# ![image.png](attachment:image.png)
# Сверточные слои.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Вектор скрытого состояния (hidden) накапливает в себе информацию.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Скалярное произведение используется как мера похожести двух слов.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Софтмакс от скалярных произведений соответствующих скрытых векторов состояний энкодера и декодера.
