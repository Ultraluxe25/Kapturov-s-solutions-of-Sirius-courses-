# %% [markdown]
# ![image.png](attachment:9971b43f-3521-43cb-a211-db0420e53586.png)

# %% [markdown]
# ![image.png](attachment:87781ae6-30c5-4279-b011-a168a26d6684.png)

# %% [markdown]
# ![image.png](attachment:d6f95442-7b2a-4f78-9011-3ff1803a1837.png)
